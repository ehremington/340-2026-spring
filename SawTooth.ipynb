# %%
cycles = 5
A = 1
T = 2*np.pi


x = []

for i in range(0, 2*cycles, 2):  #skipping by 2 since pattern repeats every 2pi
    x.append(i * T/2)  # getting values of 0, 2pi, 4pi...
    x.append((i+1) * T/2) # getting pi, 3pi, 5pi...
    x.append((i+2) * T/2 + 0.00001) # making a point for the sawtooth to drop almost straight down to 0 before restarting

pattern = [0, A/2, A]
y = pattern * cycles  # gives y values of 0, half amplitude, and full amplitude, repeating at 0

fig1, ax1 = plt.subplots()
ax1.plot(x, y)
# Out:
# [0.0, 3.141592653589793, 6.283195307179586, 6.283185307179586, 9.42477796076938, 12.566380614359172, 12.566370614359172, 15.707963267948966, 18.84956592153876, 18.84955592153876, 21.991148575128552, 25.132751228718345, 25.132741228718345, 28.274333882308138, 31.41593653589793] [0, 0.5, 1, 0, 0.5, 1, 0, 0.5, 1, 0, 0.5, 1, 0, 0.5, 1]
# Canvas(toolbar=Toolbar(toolitems=[('Home', 'Reset original view', 'home', 'home'), ('Back', 'Back to previous …
